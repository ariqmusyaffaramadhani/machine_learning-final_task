# %% [markdown]
# # Pre-Processing (for Clustering)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame, read_csv
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import matplotlib as mpl; mpl.rcParams['figure.dpi'] = 100
import seaborn as sns; sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "drive/My Drive/malin"
# Out:
# dataset_class_1.csv  dataset_clust_2.csv   training_KNN.xlsx
# dataset_class_2.csv  retail_record_4.xlsx  used_cars.csv
# dataset_clust_1.csv  testing_KNN.xlsx

# %%
data = pd.read_csv("drive/My Drive/malin/used_cars.csv")
data
# data.describe()
# Out:
#        Unnamed: 0          id  ...      lat     long
# 0               0  7034441763  ...  40.7372 -111.858
# 1               1  7034440610  ...  40.5881 -111.884
# 2               2  7034440588  ...  40.5881 -111.884
# 3               3  7034440546  ...  40.5881 -111.884
# 4               4  7034406932  ...  40.3744 -104.694
# ...           ...         ...  ...      ...      ...
# 19996       19996  7049052853  ...  46.2348 -119.128
# 19997       19997  7049052797  ...  46.5642 -120.496
# 19998       19998  7049049369  ...  46.0783 -118.293
# 19999       19999  7049042761  ...  46.5642 -120.496
# 20000       20000  7049039610  ...  46.2348 -119.128
#
# [20001 rows x 26 columns]

# %% [markdown]
# **Drop Unnecessary Feature**

# %% [markdown]
# Terdapat fitur yang memiliki count = 0 yang dapat berdampak besar saat proses missing value handling

# %%
data = data.drop(['county'], axis=1)
data.describe()
# Out:
#          Unnamed: 0            id  ...           lat          long
# count  20001.000000  2.000100e+04  ...  18970.000000  18970.000000
# mean   10000.000000  7.043199e+09  ...     40.394737    -86.300395
# std     5773.935703  4.668820e+06  ...      4.440290     18.219242
# min        0.000000  7.032597e+09  ...    -51.812200   -155.901000
# 25%     5000.000000  7.040114e+09  ...     37.273700    -80.166800
# 50%    10000.000000  7.043866e+09  ...     38.258600    -77.514200
# 75%    15000.000000  7.047065e+09  ...     44.439500    -76.238400
# max    20000.000000  7.050101e+09  ...     59.746600      9.095700
#
# [8 rows x 7 columns]

# %% [markdown]
# **Missing Value**

# %%
#drop missing value
data_miss = DataFrame.dropna(data)
data_miss
# Out:
#        Unnamed: 0          id  ...      lat     long
# 0               0  7034441763  ...  40.7372 -111.858
# 24             24  7034278551  ...  40.7499 -111.926
# 48             48  7033720842  ...  40.3179 -111.704
# 112           112  7033077397  ...  40.6557 -111.886
# 135           135  7032693370  ...  44.3550 -106.680
# ...           ...         ...  ...      ...      ...
# 19907       19907  7049230489  ...  46.2348 -119.159
# 19919       19919  7049199145  ...  45.4881 -122.580
# 19927       19927  7049187416  ...  46.2379 -119.237
# 19944       19944  7049187695  ...  46.2676 -119.215
# 19961       19961  7049141967  ...  46.2380 -119.237
#
# [2814 rows x 25 columns]

# %% [markdown]
# **Selected Feature Candidate**

# %% [markdown]
# Memilih kandidat fitur-fitur yang akan digunakan

# %%
sel_data_c = data_miss[['id','region','price','year','manufacturer','model','condition','cylinders','fuel','odometer','title_status','transmission','drive','size','type','state','lat','long']]
sel_data_c
# Out:
#                id                    region  price  ...  state      lat     long
# 0      7034441763            salt lake city  17899  ...     ut  40.7372 -111.858
# 24     7034278551            salt lake city   4600  ...     ut  40.7499 -111.926
# 48     7033720842            salt lake city  28000  ...     ut  40.3179 -111.704
# 112    7033077397            salt lake city   4000  ...     ut  40.6557 -111.886
# 135    7032693370            salt lake city  38995  ...     ut  44.3550 -106.680
# ...           ...                       ...    ...  ...    ...      ...      ...
# 19907  7049230489  kennewick-pasco-richland  11500  ...     wa  46.2348 -119.159
# 19919  7049199145  kennewick-pasco-richland  10995  ...     wa  45.4881 -122.580
# 19927  7049187416  kennewick-pasco-richland  11995  ...     wa  46.2379 -119.237
# 19944  7049187695  kennewick-pasco-richland  18995  ...     wa  46.2676 -119.215
# 19961  7049141967  kennewick-pasco-richland  11500  ...     wa  46.2380 -119.237
#
# [2814 rows x 18 columns]

# %% [markdown]
# **Data Encode**

# %% [markdown]
# Encode data yang bertipe non-numeric

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
sel_data_c['region'] = labelencoder.fit_transform(sel_data_c['region']) 
sel_data_c['manufacturer'] = labelencoder.fit_transform(sel_data_c['manufacturer']) 
sel_data_c['model'] = labelencoder.fit_transform(sel_data_c['model']) 
sel_data_c['condition'] = labelencoder.fit_transform(sel_data_c['condition']) 
sel_data_c['cylinders'] = labelencoder.fit_transform(sel_data_c['cylinders']) 
sel_data_c['fuel'] = labelencoder.fit_transform(sel_data_c['fuel']) 
sel_data_c['title_status'] = labelencoder.fit_transform(sel_data_c['title_status']) 
sel_data_c['transmission'] = labelencoder.fit_transform(sel_data_c['transmission']) 
sel_data_c['drive'] = labelencoder.fit_transform(sel_data_c['drive']) 
sel_data_c['size'] = labelencoder.fit_transform(sel_data_c['size']) 
sel_data_c['type'] = labelencoder.fit_transform(sel_data_c['type']) 
sel_data_c['state'] = labelencoder.fit_transform(sel_data_c['state']) 

sel_data_c
# Out:
#                id  region  price    year  ...  type  state      lat     long
# 0      7034441763      11  17899  2012.0  ...     4      0  40.7372 -111.858
# 24     7034278551      11   4600  2008.0  ...     9      0  40.7499 -111.926
# 48     7033720842      11  28000  2004.0  ...    10      0  40.3179 -111.704
# 112    7033077397      11   4000  2011.0  ...     9      0  40.6557 -111.886
# 135    7032693370      11  38995  2016.0  ...    10      0  44.3550 -106.680
# ...           ...     ...    ...     ...  ...   ...    ...      ...      ...
# 19907  7049230489       5  11500  2006.0  ...     3      3  46.2348 -119.159
# 19919  7049199145       5  10995  2014.0  ...     9      3  45.4881 -122.580
# 19927  7049187416       5  11995  2017.0  ...    12      3  46.2379 -119.237
# 19944  7049187695       5  18995  2019.0  ...     0      3  46.2676 -119.215
# 19961  7049141967       5  11500  2017.0  ...     9      3  46.2380 -119.237
#
# [2814 rows x 18 columns]

# %% [markdown]
# **Heat Map**

# %%
#untuk menentukan fitur-fitur yang berkorelasi cukup baik
corel = sel_data_c.corr()
top_corr = corel.index
plt.figure(figsize=(20,16))
sns.heatmap(sel_data_c[top_corr].corr(),annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# Fitur yang dipilih adalah year dan price dengan nilai 0.35

# %% [markdown]
# **Selected Feature**

# %%
sel_feat = sel_data_c[['year','price']]
sel_feat
# Out:
#          year  price
# 0      2012.0  17899
# 24     2008.0   4600
# 48     2004.0  28000
# 112    2011.0   4000
# 135    2016.0  38995
# ...       ...    ...
# 19907  2006.0  11500
# 19919  2014.0  10995
# 19927  2017.0  11995
# 19944  2019.0  18995
# 19961  2017.0  11500
#
# [2814 rows x 2 columns]

# %% [markdown]
# **Outlier Check**

# %%
# plt.scatter(sel_feat['condition'], sel_feat['odometer'],c='green')
# plt.xlabel('condition')
# plt.ylabel('odometer')
# plt.show
f, axes = plt.subplots(1, 2)
sns.boxplot(y = sel_data_c['year'], ax = axes[0])
sns.boxplot(y = sel_data_c['price'], ax = axes[1])
plt.subplots_adjust(wspace=1)

# %% [markdown]
# **Outlier Handling**

# %% [markdown]
# terdapat outlier pada kedua feature

# %%
outl = sel_feat.loc[(sel_feat['year']<2000) | (sel_feat['price']>28000)]
sdc_out = sel_feat.drop(outl.index)
sdc_out
# Out:
#          year  price
# 0      2012.0  17899
# 24     2008.0   4600
# 48     2004.0  28000
# 112    2011.0   4000
# 137    2010.0  14995
# ...       ...    ...
# 19907  2006.0  11500
# 19919  2014.0  10995
# 19927  2017.0  11995
# 19944  2019.0  18995
# 19961  2017.0  11500
#
# [2539 rows x 2 columns]

# %% [markdown]
# **2nd Outlier Check**

# %%
# plt.scatter(sdc_out['price'], sdc_out['odometer'],c='green')
# plt.xlabel('price')
# plt.ylabel('odometer')
# plt.show

f, axes = plt.subplots(1, 2)
sns.boxplot(y = sdc_out['year'], ax = axes[0])
sns.boxplot(y = sdc_out['price'], ax = axes[1])
plt.subplots_adjust(wspace=1)

# %%
sdc_out.describe()
# Out:
#               year         price
# count  2539.000000   2539.000000
# mean   2010.241827  10161.954313
# std       4.483641   6750.277523
# min    2000.000000      0.000000
# 25%    2007.000000   4997.500000
# 50%    2010.000000   7998.000000
# 75%    2014.000000  14992.500000
# max    2019.000000  28000.000000

# %% [markdown]
# **Scalling**

# %% [markdown]
# Karena terdapat gap yang cukup jauh antara nilai-nilai pada kedua fitur, maka akan dilakukan scalling

# %%
scaler = MinMaxScaler()
data_data = sdc_out.values.tolist()
scaler.fit(data_data)
sdc_scaled = scaler.transform(data_data)
new_col = ['year','price']
sdc_new = pd.DataFrame(sdc_scaled,columns=new_col)
sdc_new.to_csv('drive/My Drive/malin/dataset_clust_1.csv')
sdc_new.describe()
# Out:
#               year        price
# count  2539.000000  2539.000000
# mean      0.539044     0.362927
# std       0.235981     0.241081
# min       0.000000     0.000000
# 25%       0.368421     0.178482
# 50%       0.526316     0.285643
# 75%       0.736842     0.535446
# max       1.000000     1.000000

# %% [markdown]
# # Clustering

# %% [markdown]
# **Find Ideal K value**

# %%
#hanya untuk penentuan nilai K
from sklearn.cluster import KMeans

r = range(1,20)
square_dist = []
for i in r:
  km = KMeans(n_clusters=i)
  km = km.fit(sdc_new)
  square_dist.append(km.inertia_)

plt.plot(r,square_dist,'bx-')
plt.xlabel('K-value')
plt.ylabel('variance reduction') 
plt.show()

# %% [markdown]
# berdasarkan hasil diatas, maka k = 3

# %% [markdown]
# **K-Means Clustering**

# %%
np.random.seed(200)
k = 3
centroids = {
  i+1: [np.random.choice(sdc_new['year']),np.random.choice(sdc_new['price'])]
  for i in range(k)
}

# cen = make_centroid(sdc_new)
# k=3
fig = plt.figure(figsize=(4,4))
plt.scatter(sdc_new['year'], sdc_new['price'], color='k')
colmap = {1:'r', 2:'g', 3:'b'}
for i in centroids.keys():
  plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
##assignment stage

def assignment(df, centroids):
  for i in centroids.keys():
    df['distance_from_{}'.format(i)] = (
        np.sqrt(
            (df['year']-centroids[i][0])**2 + (df['price']-centroids[i][0])**2
        )
    )
  centroid_distance_cols = ['distance_from_{}'.format(i) for i in centroids.keys()]
  df['closest'] = df.loc[:, centroid_distance_cols].idxmin(axis=1)
  df['closest'] = df['closest'].map(lambda x: int(x.lstrip('distance_from_')))
  df['color'] = df['closest'].map(lambda x: colmap[x])
  return df
df = assignment(sdc_new, centroids)

fig = plt.figure(figsize=(4,4))
plt.scatter(df['year'], df['price'], color=df['color'], alpha=0.5, edgecolors='k')
for i in centroids.keys():
  plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
## update stage
import copy
old_centroids = copy.deepcopy(centroids)

def update_cen(k):
  for i in centroids.keys():
    centroids[i][0] = np.mean(df[df['closest']==i]['year'])
    centroids[i][1] = np.mean(df[df['closest']==i]['price'])
  return k

centroids = update_cen(centroids)

fig = plt.figure(figsize=(4,4))
ax = plt.axes()
plt.scatter(df['year'], df['price'], color=df['color'], alpha=0.5, edgecolors='k')
for i in centroids.keys():
  plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
## loop until centroid not change

# df = assignment(df, centroids)
while True:
  closest_cen = df['closest'].copy(deep=True)
  centroids = update_cen(centroids)
  df = assignment(df, centroids)
  if closest_cen.equals(df['closest']):
    break
  
fig = plt.figure(figsize=(4,4))
plt.scatter(df['year'], df['price'], color=df['color'], alpha=0.5, edgecolors='k')
for i in centroids.keys():
  plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %% [markdown]
# # Pre-Processing (for Classification)

# %%
df = sel_data_c #dari Pre-Processing (for Clustering)
df.describe()
# Out:
#                  id       region  ...          lat         long
# count  2.814000e+03  2814.000000  ...  2814.000000  2814.000000
# mean   7.042809e+09     9.142502  ...    40.288347   -79.701684
# std    4.482351e+06     4.754097  ...     3.664149    11.541405
# min    7.032597e+09     0.000000  ...    30.041600  -122.783000
# 25%    7.039535e+09     6.000000  ...    37.336800   -79.118100
# 50%    7.043322e+09     9.000000  ...    38.382950   -77.468100
# 75%    7.046854e+09    14.000000  ...    44.439500   -73.210200
# max    7.050097e+09    15.000000  ...    53.032400   -70.453900
#
# [8 rows x 18 columns]

# %% [markdown]
# **Correlation Check**

# %% [markdown]
# memeriksa korelasi antar fitur

# %%
# corel = sel_data_c.corr()
# top_corr = corel.index
# plt.figure(figsize=(1000,1000))
# plt.show()
# g=sns.heatmap(sel_data_c[top_corr].corr(),annot=True,cmap="RdYlGn")

plt.figure(figsize=(20,16))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#correlation dengan variabel targer
cor_target = abs(cor['condition'])

#checking highly correlated feature w/ condition
#memeriksa nilai korelasi tertinggi pada fitur-fitur berdasarkan target(condition)
rel_feat = cor_target[cor_target>0.1]
rel_feat
# Out:
# year            0.139979
# condition       1.000000
# odometer        0.127944
# title_status    0.113083
# drive           0.115289
# Name: condition, dtype: float64

# %% [markdown]
# terdapat 4 fitur yang memiliki nilai korelasi yang cukup tinggi terhadap fitur targer (condition), dilakukan pemeriksaan variabel independen.

# %%
print(df[['year','odometer','title_status','drive']].corr())
# Out:
#                   year  odometer  title_status     drive
# year          1.000000 -0.322274      0.012871 -0.172332
# odometer     -0.322274  1.000000     -0.069712 -0.063406
# title_status  0.012871 -0.069712      1.000000  0.035379
# drive        -0.172332 -0.063406      0.035379  1.000000

# %% [markdown]
# fitur odometer dihapus

# %%
df = df[['year','title_status','drive','condition']]
df #dataframe final yang akan diklasifikasi
df.to_csv('drive/My Drive/malin/dataset_class_1.csv')

# %% [markdown]
# **Independent & Dependent Variable**

# %% [markdown]
# Menentukan fitur yang menjadi variabel independen dan dependen

# %%
#independent
x = df.drop(['condition'], axis=1) 

#dependent
y = df['condition']

# %% [markdown]
# **Data Testing & Data Training**

# %% [markdown]
# Memisahkan dataset menjadi data test & train

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 123)

# %% [markdown]
# # Classification

# %% [markdown]
# **K-Nearest Neighboor**

# %% [markdown]
# Klasifikasi menggunakan metode KNN

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn import metrics 
from sklearn.metrics import f1_score as f1
from sklearn.metrics import accuracy_score as acc_score
from sklearn.metrics import precision_score as prec
from sklearn.metrics import recall_score as recall

from sklearn.neighbors import KNeighborsClassifier

k = 5

knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(x_train,y_train)
y_pred_knn = knn.predict(x_test)

#evaluasi
print("Accuracy  : ", acc_score(y_test,y_pred_knn))
print("F1-Score  : ", f1(y_test,y_pred_knn, average='macro'))
print("Precision : ", prec(y_test,y_pred_knn, average='macro'))
print("Recall    : ", recall(y_test,y_pred_knn, average='macro'))
# Out:
# Accuracy  :  0.5754884547069272
# F1-Score  :  0.28097180647055353
# Precision :  0.3343844657078093
# Recall    :  0.2641197939842648
